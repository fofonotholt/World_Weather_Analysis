# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the datetime module from the datetime library.
from datetime import datetime
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 731

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | namibe
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | avarua
# Processing Record 6 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 1 | orel
# Processing Record 8 of Set 1 | severo-kurilsk
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | challans
# Processing Record 13 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | san quintin
# Processing Record 16 of Set 1 | hambantota
# Processing Record 17 of Set 1 | menongue
# Processing Record 18 of Set 1 | sungairaya
# Processing Record 19 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 21 of Set 1 | dikson
# Processing Record 22 of Set 1 | lompoc
# Processing Record 23 of Set 1 | smithers
# Processing Record 24 of Set 1 | barrow
# Processing Record 25 of Set 1 | wanning
# Processing Record 26 of Set 1 | contamana
# Processing Record 27 of Set 1 | iroquois falls
# Processing Record 28 of Set 1 | broome
# Processing Record 29 of Set 1 | kavieng
# Processing Record 30 of Set 1 | port hardy
# Processing Record 31 of Set 1 | san luis rio colorado
# Processing Record 32 of Set 1 | longyearbyen
# Processing Record 33 of Set 1 | necochea
# Processing Record 34 of Set 1 | bathsheba
# Processing Record 35 of Set 1 | avare
# Processing Record 36 of Set 1 | ambilobe
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | ayni
# Processing Record 39 of Set 1 | kargasok
# Processing Record 40 of Set 1 | aberystwyth
# Processing Record 41 of Set 1 | rikitea
# Processing Record 42 of Set 1 | qaanaaq
# Processing Record 43 of Set 1 | okhotsk
# Processing Record 44 of Set 1 | gamba
# Processing Record 45 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 1 | bredasdorp
# Processing Record 47 of Set 1 | pevek
# Processing Record 48 of Set 1 | mount gambier
# Processing Record 49 of Set 1 | lebu
# Processing Record 50 of Set 1 | devonport
# Processing Record 1 of Set 2 | pokrovka
# Processing Record 2 of Set 2 | ilulissat
# Processing Record 3 of Set 2 | kunya
# Processing Record 4 of Set 2 | faanui
# Processing Record 5 of Set 2 | kainantu
# Processing Record 6 of Set 2 | rudbar
# Processing Record 7 of Set 2 | carnarvon
# Processing Record 8 of Set 2 | ixtapa
# Processing Record 9 of Set 2 | tezu
# Processing Record 10 of Set 2 | turukhansk
# Processing Record 11 of Set 2 | kutum
# Processing Record 12 of Set 2 | giyani
# Processing Record 13 of Set 2 | ushuaia
# Processing Record 14 of Set 2 | provideniya
# Processing Record 15 of Set 2 | busselton
# Processing Record 16 of Set 2 | nuuk
# Processing Record 17 of Set 2 | mahaicony
# City not found. Skipping...
# Processing Record 18 of Set 2 | havre-saint-pierre
# Processing Record 19 of Set 2 | umm lajj
# Processing Record 20 of Set 2 | bethel
# Processing Record 21 of Set 2 | saldanha
# Processing Record 22 of Set 2 | vaini
# Processing Record 23 of Set 2 | butaritari
# Processing Record 24 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 2 | ishigaki
# Processing Record 26 of Set 2 | tortoli
# Processing Record 27 of Set 2 | bolshoye pikino
# City not found. Skipping...
# Processing Record 28 of Set 2 | bacuit
# City not found. Skipping...
# Processing Record 29 of Set 2 | airai
# Processing Record 30 of Set 2 | saint anthony
# Processing Record 31 of Set 2 | tarakan
# Processing Record 32 of Set 2 | margate
# Processing Record 33 of Set 2 | lamar
# Processing Record 34 of Set 2 | kushima
# Processing Record 35 of Set 2 | hamilton
# Processing Record 36 of Set 2 | kodinsk
# Processing Record 37 of Set 2 | requena
# Processing Record 38 of Set 2 | bambanglipuro
# Processing Record 39 of Set 2 | lamu
# Processing Record 40 of Set 2 | sechura
# Processing Record 41 of Set 2 | tazovskiy
# Processing Record 42 of Set 2 | mitu
# Processing Record 43 of Set 2 | nikolskoye
# Processing Record 44 of Set 2 | magdalena
# Processing Record 45 of Set 2 | kapaa
# Processing Record 46 of Set 2 | sangar
# Processing Record 47 of Set 2 | phonhong
# Processing Record 48 of Set 2 | kodiak
# Processing Record 49 of Set 2 | georgetown
# Processing Record 50 of Set 2 | yerbogachen
# Processing Record 1 of Set 3 | nabire
# Processing Record 2 of Set 3 | la ronge
# Processing Record 3 of Set 3 | bocaranga
# City not found. Skipping...
# Processing Record 4 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 3 | yangambi
# Processing Record 6 of Set 3 | angoche
# Processing Record 7 of Set 3 | henties bay
# Processing Record 8 of Set 3 | ulverstone
# Processing Record 9 of Set 3 | panaba
# Processing Record 10 of Set 3 | itarema
# Processing Record 11 of Set 3 | mareeba
# Processing Record 12 of Set 3 | upernavik
# Processing Record 13 of Set 3 | evensk
# Processing Record 14 of Set 3 | qurayyat
# Processing Record 15 of Set 3 | lagoa
# Processing Record 16 of Set 3 | port-cartier
# Processing Record 17 of Set 3 | roma
# Processing Record 18 of Set 3 | tuktoyaktuk
# Processing Record 19 of Set 3 | college
# Processing Record 20 of Set 3 | saskylakh
# Processing Record 21 of Set 3 | chokurdakh
# Processing Record 22 of Set 3 | hermanus
# Processing Record 23 of Set 3 | bitung
# Processing Record 24 of Set 3 | saint george
# Processing Record 25 of Set 3 | anloga
# Processing Record 26 of Set 3 | kokopo
# Processing Record 27 of Set 3 | kalmunai
# Processing Record 28 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 3 | inta
# Processing Record 30 of Set 3 | troitskoye
# Processing Record 31 of Set 3 | buala
# Processing Record 32 of Set 3 | nazarovo
# Processing Record 33 of Set 3 | puerto ayora
# Processing Record 34 of Set 3 | mahebourg
# Processing Record 35 of Set 3 | kargil
# Processing Record 36 of Set 3 | port alfred
# Processing Record 37 of Set 3 | bandar-e lengeh
# Processing Record 38 of Set 3 | braganca
# Processing Record 39 of Set 3 | new norfolk
# Processing Record 40 of Set 3 | barcarena
# Processing Record 41 of Set 3 | cidreira
# Processing Record 42 of Set 3 | srednekolymsk
# Processing Record 43 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 3 | kidal
# Processing Record 45 of Set 3 | laguna
# Processing Record 46 of Set 3 | kochki
# Processing Record 47 of Set 3 | beaverlodge
# Processing Record 48 of Set 3 | luderitz
# Processing Record 49 of Set 3 | arraial do cabo
# Processing Record 50 of Set 3 | concepcion del oro
# Processing Record 1 of Set 4 | asau
# Processing Record 2 of Set 4 | savannakhet
# Processing Record 3 of Set 4 | khatanga
# Processing Record 4 of Set 4 | fangshan
# Processing Record 5 of Set 4 | tasiilaq
# Processing Record 6 of Set 4 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 7 of Set 4 | hilo
# Processing Record 8 of Set 4 | haines junction
# Processing Record 9 of Set 4 | port hueneme
# Processing Record 10 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 4 | karratha
# Processing Record 12 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 4 | babati
# Processing Record 14 of Set 4 | hit
# Processing Record 15 of Set 4 | pafos
# Processing Record 16 of Set 4 | tamasane
# Processing Record 17 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 18 of Set 4 | hemsedal
# Processing Record 19 of Set 4 | tiksi
# Processing Record 20 of Set 4 | port lincoln
# Processing Record 21 of Set 4 | bereda
# Processing Record 22 of Set 4 | tuggurt
# City not found. Skipping...
# Processing Record 23 of Set 4 | esperance
# Processing Record 24 of Set 4 | shetpe
# Processing Record 25 of Set 4 | maua
# Processing Record 26 of Set 4 | yar-sale
# Processing Record 27 of Set 4 | cabo san lucas
# Processing Record 28 of Set 4 | yellowknife
# Processing Record 29 of Set 4 | sept-iles
# Processing Record 30 of Set 4 | sakakah
# Processing Record 31 of Set 4 | arlit
# Processing Record 32 of Set 4 | billings
# Processing Record 33 of Set 4 | sinegorye
# Processing Record 34 of Set 4 | say
# Processing Record 35 of Set 4 | port hawkesbury
# Processing Record 36 of Set 4 | puerto narino
# Processing Record 37 of Set 4 | cheuskiny
# City not found. Skipping...
# Processing Record 38 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 4 | loreto
# Processing Record 40 of Set 4 | nacala
# Processing Record 41 of Set 4 | itapirapua
# Processing Record 42 of Set 4 | matagami
# Processing Record 43 of Set 4 | antofagasta
# Processing Record 44 of Set 4 | east london
# Processing Record 45 of Set 4 | changji
# Processing Record 46 of Set 4 | puerto leguizamo
# Processing Record 47 of Set 4 | abalak
# Processing Record 48 of Set 4 | adrar
# Processing Record 49 of Set 4 | cao bang
# Processing Record 50 of Set 4 | saravena
# Processing Record 1 of Set 5 | shkotovo-26
# City not found. Skipping...
# Processing Record 2 of Set 5 | kruisfontein
# Processing Record 3 of Set 5 | solhan
# Processing Record 4 of Set 5 | touros
# Processing Record 5 of Set 5 | ovre ardal
# Processing Record 6 of Set 5 | souillac
# Processing Record 7 of Set 5 | novorudnyy
# Processing Record 8 of Set 5 | taltal
# Processing Record 9 of Set 5 | falealupo
# City not found. Skipping...
# Processing Record 10 of Set 5 | iqaluit
# Processing Record 11 of Set 5 | vila
# Processing Record 12 of Set 5 | joshimath
# Processing Record 13 of Set 5 | biak
# Processing Record 14 of Set 5 | hasaki
# Processing Record 15 of Set 5 | mar del plata
# Processing Record 16 of Set 5 | kaitangata
# Processing Record 17 of Set 5 | tessalit
# Processing Record 18 of Set 5 | kandrian
# Processing Record 19 of Set 5 | hornepayne
# Processing Record 20 of Set 5 | bowen
# Processing Record 21 of Set 5 | buraydah
# Processing Record 22 of Set 5 | kangaatsiaq
# Processing Record 23 of Set 5 | port elizabeth
# Processing Record 24 of Set 5 | salalah
# Processing Record 25 of Set 5 | moussoro
# Processing Record 26 of Set 5 | cherskiy
# Processing Record 27 of Set 5 | lata
# Processing Record 28 of Set 5 | deputatskiy
# Processing Record 29 of Set 5 | ugento
# Processing Record 30 of Set 5 | atuona
# Processing Record 31 of Set 5 | catamarca
# Processing Record 32 of Set 5 | labuan
# Processing Record 33 of Set 5 | miracema do tocantins
# Processing Record 34 of Set 5 | fortuna
# Processing Record 35 of Set 5 | klaksvik
# Processing Record 36 of Set 5 | dolbeau
# City not found. Skipping...
# Processing Record 37 of Set 5 | vaovai
# City not found. Skipping...
# Processing Record 38 of Set 5 | copiapo
# Processing Record 39 of Set 5 | bengkulu
# Processing Record 40 of Set 5 | huainan
# Processing Record 41 of Set 5 | naze
# Processing Record 42 of Set 5 | opuwo
# Processing Record 43 of Set 5 | zhangjiakou
# Processing Record 44 of Set 5 | warmbad
# Processing Record 45 of Set 5 | moroto
# Processing Record 46 of Set 5 | roebourne
# Processing Record 47 of Set 5 | harper
# Processing Record 48 of Set 5 | camacha
# Processing Record 49 of Set 5 | yulara
# Processing Record 50 of Set 5 | jardim
# Processing Record 1 of Set 6 | sao joao da barra
# Processing Record 2 of Set 6 | grand gaube
# Processing Record 3 of Set 6 | ituni
# City not found. Skipping...
# Processing Record 4 of Set 6 | sao filipe
# Processing Record 5 of Set 6 | aswan
# Processing Record 6 of Set 6 | vestmanna
# Processing Record 7 of Set 6 | sayalgudi
# City not found. Skipping...
# Processing Record 8 of Set 6 | belmonte
# Processing Record 9 of Set 6 | ponta do sol
# Processing Record 10 of Set 6 | alyangula
# Processing Record 11 of Set 6 | bandarbeyla
# Processing Record 12 of Set 6 | valadares
# Processing Record 13 of Set 6 | hoyanger
# Processing Record 14 of Set 6 | northam
# Processing Record 15 of Set 6 | sangmelima
# Processing Record 16 of Set 6 | castro
# Processing Record 17 of Set 6 | carman
# Processing Record 18 of Set 6 | maltahohe
# Processing Record 19 of Set 6 | praia da vitoria
# Processing Record 20 of Set 6 | teya
# Processing Record 21 of Set 6 | saint-philippe
# Processing Record 22 of Set 6 | krasnyy chikoy
# Processing Record 23 of Set 6 | riaba
# City not found. Skipping...
# Processing Record 24 of Set 6 | lysyye gory
# Processing Record 25 of Set 6 | immokalee
# Processing Record 26 of Set 6 | lashio
# Processing Record 27 of Set 6 | coihaique
# Processing Record 28 of Set 6 | tucurui
# Processing Record 29 of Set 6 | cavalcante
# Processing Record 30 of Set 6 | oksbol
# Processing Record 31 of Set 6 | gawler
# Processing Record 32 of Set 6 | ardino
# Processing Record 33 of Set 6 | guanica
# Processing Record 34 of Set 6 | codrington
# Processing Record 35 of Set 6 | pedasi
# Processing Record 36 of Set 6 | west odessa
# Processing Record 37 of Set 6 | alofi
# Processing Record 38 of Set 6 | suratgarh
# Processing Record 39 of Set 6 | fauldhouse
# Processing Record 40 of Set 6 | imeni babushkina
# Processing Record 41 of Set 6 | ilebo
# Processing Record 42 of Set 6 | qaqortoq
# Processing Record 43 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 6 | okandja
# City not found. Skipping...
# Processing Record 45 of Set 6 | itaituba
# Processing Record 46 of Set 6 | vardo
# Processing Record 47 of Set 6 | ormara
# Processing Record 48 of Set 6 | la macarena
# Processing Record 49 of Set 6 | kieta
# Processing Record 50 of Set 6 | umm durman
# City not found. Skipping...
# Processing Record 1 of Set 7 | ayame
# Processing Record 2 of Set 7 | nanortalik
# Processing Record 3 of Set 7 | kanniyakumari
# Processing Record 4 of Set 7 | nikolayevsk-na-amure
# Processing Record 5 of Set 7 | grootfontein
# Processing Record 6 of Set 7 | egvekinot
# Processing Record 7 of Set 7 | ayagoz
# Processing Record 8 of Set 7 | ancud
# Processing Record 9 of Set 7 | kununurra
# Processing Record 10 of Set 7 | sivaki
# Processing Record 11 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 12 of Set 7 | todos santos
# Processing Record 13 of Set 7 | cairns
# Processing Record 14 of Set 7 | chuy
# Processing Record 15 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 7 | batemans bay
# Processing Record 17 of Set 7 | ust-tsilma
# Processing Record 18 of Set 7 | oksfjord
# Processing Record 19 of Set 7 | victoria
# Processing Record 20 of Set 7 | kimbe
# Processing Record 21 of Set 7 | sedelnikovo
# City not found. Skipping...
# Processing Record 22 of Set 7 | albertville
# Processing Record 23 of Set 7 | thompson
# Processing Record 24 of Set 7 | iskateley
# Processing Record 25 of Set 7 | yarkovo
# Processing Record 26 of Set 7 | partur
# Processing Record 27 of Set 7 | carmo do rio verde
# Processing Record 28 of Set 7 | takoradi
# Processing Record 29 of Set 7 | hithadhoo
# Processing Record 30 of Set 7 | narsaq
# Processing Record 31 of Set 7 | sekoma
# Processing Record 32 of Set 7 | tsabong
# Processing Record 33 of Set 7 | kilrush
# Processing Record 34 of Set 7 | antalaha
# Processing Record 35 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 7 | polyanka
# Processing Record 37 of Set 7 | leningradskiy
# Processing Record 38 of Set 7 | jambi
# Processing Record 39 of Set 7 | guerrero negro
# Processing Record 40 of Set 7 | madang
# Processing Record 41 of Set 7 | mancio lima
# Processing Record 42 of Set 7 | benjamin constant
# Processing Record 43 of Set 7 | pasinler
# Processing Record 44 of Set 7 | tougue
# Processing Record 45 of Set 7 | mizdah
# Processing Record 46 of Set 7 | sitka
# Processing Record 47 of Set 7 | harwich
# Processing Record 48 of Set 7 | almaznyy
# Processing Record 49 of Set 7 | sinnamary
# Processing Record 50 of Set 7 | sovetskiy
# Processing Record 1 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 8 | husavik
# Processing Record 3 of Set 8 | coahuayana
# Processing Record 4 of Set 8 | ponta delgada
# Processing Record 5 of Set 8 | rechitsy
# Processing Record 6 of Set 8 | ribeira grande
# Processing Record 7 of Set 8 | geraldton
# Processing Record 8 of Set 8 | biasca
# Processing Record 9 of Set 8 | vanimo
# Processing Record 10 of Set 8 | vaitape
# Processing Record 11 of Set 8 | laramie
# Processing Record 12 of Set 8 | hue
# Processing Record 13 of Set 8 | tisul
# Processing Record 14 of Set 8 | pochutla
# Processing Record 15 of Set 8 | tuatapere
# Processing Record 16 of Set 8 | huallanca
# Processing Record 17 of Set 8 | port hedland
# Processing Record 18 of Set 8 | altay
# Processing Record 19 of Set 8 | khartoum
# Processing Record 20 of Set 8 | guaratinga
# Processing Record 21 of Set 8 | kiunga
# Processing Record 22 of Set 8 | kampot
# Processing Record 23 of Set 8 | vitim
# Processing Record 24 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 25 of Set 8 | marrakesh
# Processing Record 26 of Set 8 | luganville
# Processing Record 27 of Set 8 | walvis bay
# Processing Record 28 of Set 8 | padang
# Processing Record 29 of Set 8 | sola
# Processing Record 30 of Set 8 | xuddur
# Processing Record 31 of Set 8 | maningrida
# Processing Record 32 of Set 8 | craigieburn
# Processing Record 33 of Set 8 | ekibastuz
# Processing Record 34 of Set 8 | bom jesus
# Processing Record 35 of Set 8 | caravelas
# Processing Record 36 of Set 8 | salta
# Processing Record 37 of Set 8 | okato
# Processing Record 38 of Set 8 | ibra
# Processing Record 39 of Set 8 | kpandae
# Processing Record 40 of Set 8 | ekpoma
# Processing Record 41 of Set 8 | norman wells
# Processing Record 42 of Set 8 | esil
# Processing Record 43 of Set 8 | jalu
# Processing Record 44 of Set 8 | tura
# Processing Record 45 of Set 8 | manokwari
# Processing Record 46 of Set 8 | litoral del san juan
# City not found. Skipping...
# Processing Record 47 of Set 8 | yaan
# Processing Record 48 of Set 8 | sambava
# Processing Record 49 of Set 8 | sisophon
# Processing Record 50 of Set 8 | la asuncion
# Processing Record 1 of Set 9 | poum
# Processing Record 2 of Set 9 | namatanai
# Processing Record 3 of Set 9 | bambous virieux
# Processing Record 4 of Set 9 | ahipara
# Processing Record 5 of Set 9 | towada
# Processing Record 6 of Set 9 | gladstone
# Processing Record 7 of Set 9 | ostrovnoy
# Processing Record 8 of Set 9 | arman
# Processing Record 9 of Set 9 | kashi
# Processing Record 10 of Set 9 | cockburn town
# Processing Record 11 of Set 9 | belyy yar
# Processing Record 12 of Set 9 | la rioja
# Processing Record 13 of Set 9 | torbay
# Processing Record 14 of Set 9 | ambanja
# Processing Record 15 of Set 9 | dingle
# Processing Record 16 of Set 9 | hualmay
# Processing Record 17 of Set 9 | mnogovershinnyy
# Processing Record 18 of Set 9 | kabompo
# Processing Record 19 of Set 9 | villa maria
# Processing Record 20 of Set 9 | khani
# Processing Record 21 of Set 9 | sicamous
# Processing Record 22 of Set 9 | pocone
# Processing Record 23 of Set 9 | port blair
# Processing Record 24 of Set 9 | marsh harbour
# Processing Record 25 of Set 9 | punta alta
# Processing Record 26 of Set 9 | conceicao do araguaia
# Processing Record 27 of Set 9 | bobcaygeon
# Processing Record 28 of Set 9 | dharchula
# Processing Record 29 of Set 9 | nago
# Processing Record 30 of Set 9 | zamora
# Processing Record 31 of Set 9 | boa vista
# Processing Record 32 of Set 9 | porto seguro
# Processing Record 33 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 34 of Set 9 | indianola
# Processing Record 35 of Set 9 | eyl
# Processing Record 36 of Set 9 | san vicente
# Processing Record 37 of Set 9 | dinsor
# City not found. Skipping...
# Processing Record 38 of Set 9 | vanavara
# Processing Record 39 of Set 9 | kungurtug
# Processing Record 40 of Set 9 | mentok
# City not found. Skipping...
# Processing Record 41 of Set 9 | genhe
# Processing Record 42 of Set 9 | port-gentil
# Processing Record 43 of Set 9 | aitape
# Processing Record 44 of Set 9 | nome
# Processing Record 45 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 9 | tolaga bay
# Processing Record 47 of Set 9 | selfoss
# Processing Record 48 of Set 9 | kamal
# Processing Record 49 of Set 9 | gisborne
# Processing Record 50 of Set 9 | sabang
# Processing Record 1 of Set 10 | scarborough
# Processing Record 2 of Set 10 | fairbanks
# Processing Record 3 of Set 10 | plettenberg bay
# Processing Record 4 of Set 10 | bogorodskoye
# Processing Record 5 of Set 10 | mondovi
# Processing Record 6 of Set 10 | denpasar
# Processing Record 7 of Set 10 | batticaloa
# Processing Record 8 of Set 10 | hobbs
# Processing Record 9 of Set 10 | muros
# Processing Record 10 of Set 10 | hashtrud
# Processing Record 11 of Set 10 | sao felix do xingu
# Processing Record 12 of Set 10 | youghal
# Processing Record 13 of Set 10 | zainsk
# Processing Record 14 of Set 10 | hailey
# Processing Record 15 of Set 10 | bokspits
# City not found. Skipping...
# Processing Record 16 of Set 10 | qabis
# City not found. Skipping...
# Processing Record 17 of Set 10 | sibolga
# Processing Record 18 of Set 10 | myitkyina
# Processing Record 19 of Set 10 | san pedro
# Processing Record 20 of Set 10 | hofn
# Processing Record 21 of Set 10 | ler
# Processing Record 22 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 23 of Set 10 | sobolevo
# Processing Record 24 of Set 10 | berlevag
# Processing Record 25 of Set 10 | high level
# Processing Record 26 of Set 10 | isangel
# Processing Record 27 of Set 10 | panacan
# Processing Record 28 of Set 10 | makinsk
# Processing Record 29 of Set 10 | mkushi
# Processing Record 30 of Set 10 | atar
# Processing Record 31 of Set 10 | russell
# Processing Record 32 of Set 10 | lorengau
# Processing Record 33 of Set 10 | marquette
# Processing Record 34 of Set 10 | ust-maya
# Processing Record 35 of Set 10 | araouane
# Processing Record 36 of Set 10 | pechory
# Processing Record 37 of Set 10 | kirby
# Processing Record 38 of Set 10 | voh
# Processing Record 39 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 10 | strezhevoy
# Processing Record 41 of Set 10 | vrangel
# Processing Record 42 of Set 10 | ajdabiya
# Processing Record 43 of Set 10 | ullapool
# Processing Record 44 of Set 10 | leshan
# Processing Record 45 of Set 10 | chara
# Processing Record 46 of Set 10 | kroya
# Processing Record 47 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 48 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 10 | kenai
# Processing Record 50 of Set 10 | lazaro cardenas
# Processing Record 1 of Set 11 | clyde river
# Processing Record 2 of Set 11 | martinsville
# Processing Record 3 of Set 11 | ternate
# Processing Record 4 of Set 11 | homa bay
# Processing Record 5 of Set 11 | edd
# Processing Record 6 of Set 11 | lodja
# Processing Record 7 of Set 11 | kryve ozero
# Processing Record 8 of Set 11 | esmeraldas
# Processing Record 9 of Set 11 | pacific grove
# Processing Record 10 of Set 11 | takaka
# Processing Record 11 of Set 11 | iquitos
# Processing Record 12 of Set 11 | mount pleasant
# Processing Record 13 of Set 11 | port keats
# Processing Record 14 of Set 11 | fort nelson
# Processing Record 15 of Set 11 | opole lubelskie
# Processing Record 16 of Set 11 | kussnacht
# Processing Record 17 of Set 11 | dovers
# Processing Record 18 of Set 11 | quatre cocos
# Processing Record 19 of Set 11 | puntarenas
# Processing Record 20 of Set 11 | susurluk
# Processing Record 21 of Set 11 | tahta
# Processing Record 22 of Set 11 | payakumbuh
# Processing Record 23 of Set 11 | malangali
# Processing Record 24 of Set 11 | gat
# Processing Record 25 of Set 11 | aleksandrovsk-sakhalinskiy
# Processing Record 26 of Set 11 | goderich
# Processing Record 27 of Set 11 | aykhal
# Processing Record 28 of Set 11 | honiara
# Processing Record 29 of Set 11 | chingirlau
# Processing Record 30 of Set 11 | boende
# Processing Record 31 of Set 11 | la romana
# Processing Record 32 of Set 11 | katete
# Processing Record 33 of Set 11 | xiamen
# Processing Record 34 of Set 11 | buchanan
# Processing Record 35 of Set 11 | deqing
# Processing Record 36 of Set 11 | balotra
# Processing Record 37 of Set 11 | amapa
# Processing Record 38 of Set 11 | zhezkazgan
# Processing Record 39 of Set 11 | avdon
# Processing Record 40 of Set 11 | rio grande
# Processing Record 41 of Set 11 | santa catarina de tepehuanes
# Processing Record 42 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 43 of Set 11 | champerico
# Processing Record 44 of Set 11 | lakselv
# Processing Record 45 of Set 11 | timizart
# Processing Record 46 of Set 11 | santiago del estero
# Processing Record 47 of Set 11 | kyabe
# Processing Record 48 of Set 11 | marzuq
# Processing Record 49 of Set 11 | puerto ayacucho
# Processing Record 50 of Set 11 | willemstad
# Processing Record 1 of Set 12 | blonduos
# City not found. Skipping...
# Processing Record 2 of Set 12 | cururupu
# Processing Record 3 of Set 12 | tres arroyos
# Processing Record 4 of Set 12 | dibulla
# Processing Record 5 of Set 12 | bloomfield
# Processing Record 6 of Set 12 | agadez
# Processing Record 7 of Set 12 | halifax
# Processing Record 8 of Set 12 | rawson
# Processing Record 9 of Set 12 | najran
# Processing Record 10 of Set 12 | bud
# Processing Record 11 of Set 12 | peniche
# Processing Record 12 of Set 12 | tilichiki
# Processing Record 13 of Set 12 | cabedelo
# Processing Record 14 of Set 12 | vlore
# Processing Record 15 of Set 12 | sedalia
# Processing Record 16 of Set 12 | katsuura
# Processing Record 17 of Set 12 | kalamakion
# City not found. Skipping...
# Processing Record 18 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 12 | san jose
# Processing Record 20 of Set 12 | abashiri
# Processing Record 21 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 22 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 23 of Set 12 | ephrata
# Processing Record 24 of Set 12 | christiansburg
# Processing Record 25 of Set 12 | meulaboh
# Processing Record 26 of Set 12 | los llanos de aridane
# Processing Record 27 of Set 12 | santa ana
# Processing Record 28 of Set 12 | cumberland
# Processing Record 29 of Set 12 | bartica
# Processing Record 30 of Set 12 | mercedes
# Processing Record 31 of Set 12 | chikwawa
# Processing Record 32 of Set 12 | sayaxche
# Processing Record 33 of Set 12 | sergeyevka
# Processing Record 34 of Set 12 | chuka
# Processing Record 35 of Set 12 | truro
# Processing Record 36 of Set 12 | komsomolskiy
# Processing Record 37 of Set 12 | dan khun thot
# Processing Record 38 of Set 12 | baraboo
# Processing Record 39 of Set 12 | guaimaro
# Processing Record 40 of Set 12 | batagay-alyta
# Processing Record 41 of Set 12 | tongliao
# Processing Record 42 of Set 12 | sioux lookout
# Processing Record 43 of Set 12 | kavaratti
# Processing Record 44 of Set 12 | zandvoort
# Processing Record 45 of Set 12 | poso
# Processing Record 46 of Set 12 | pisco
# Processing Record 47 of Set 12 | coquimbo
# Processing Record 48 of Set 12 | kamenka
# Processing Record 49 of Set 12 | xai-xai
# Processing Record 50 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 13 | hammerfest
# Processing Record 2 of Set 13 | shulan
# Processing Record 3 of Set 13 | alice springs
# Processing Record 4 of Set 13 | ferrol
# Processing Record 5 of Set 13 | fernley
# Processing Record 6 of Set 13 | grand forks
# Processing Record 7 of Set 13 | sint-gillis-waas
# Processing Record 8 of Set 13 | saint-pierre
# Processing Record 9 of Set 13 | tuy hoa
# Processing Record 10 of Set 13 | luwuk
# Processing Record 11 of Set 13 | paita
# Processing Record 12 of Set 13 | te anau
# Processing Record 13 of Set 13 | pandamatenga
# Processing Record 14 of Set 13 | kamina
# Processing Record 15 of Set 13 | fereydun kenar
# Processing Record 16 of Set 13 | beloha
# Processing Record 17 of Set 13 | esna
# Processing Record 18 of Set 13 | bodden town
# Processing Record 19 of Set 13 | baiyin
# Processing Record 20 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 21 of Set 13 | bustonkala
# City not found. Skipping...
# Processing Record 22 of Set 13 | peru
# Processing Record 23 of Set 13 | waipawa
# Processing Record 24 of Set 13 | tyubuk
# Processing Record 25 of Set 13 | nhulunbuy
# Processing Record 26 of Set 13 | piacabucu
# Processing Record 27 of Set 13 | hay river
# Processing Record 28 of Set 13 | acapulco
# Processing Record 29 of Set 13 | kharagauli
# Processing Record 30 of Set 13 | olafsvik
# Processing Record 31 of Set 13 | igarka
# Processing Record 32 of Set 13 | huesca
# Processing Record 33 of Set 13 | maceio
# Processing Record 34 of Set 13 | porto santo
# Processing Record 35 of Set 13 | san roque
# Processing Record 36 of Set 13 | ye
# City not found. Skipping...
# Processing Record 37 of Set 13 | westport
# Processing Record 38 of Set 13 | dawei
# Processing Record 39 of Set 13 | hami
# Processing Record 40 of Set 13 | zlatoustovsk
# City not found. Skipping...
# Processing Record 41 of Set 13 | baykit
# Processing Record 42 of Set 13 | brownsburg
# Processing Record 43 of Set 13 | tsiroanomandidy
# Processing Record 44 of Set 13 | raahe
# Processing Record 45 of Set 13 | virginia beach
# Processing Record 46 of Set 13 | comodoro rivadavia
# Processing Record 47 of Set 13 | yining
# Processing Record 48 of Set 13 | chodavaram
# Processing Record 49 of Set 13 | terme
# Processing Record 50 of Set 13 | kahului
# Processing Record 1 of Set 14 | wasilla
# Processing Record 2 of Set 14 | celestun
# Processing Record 3 of Set 14 | mastic beach
# Processing Record 4 of Set 14 | smolenskoye
# Processing Record 5 of Set 14 | vengerovo
# Processing Record 6 of Set 14 | vila franca do campo
# Processing Record 7 of Set 14 | sur
# Processing Record 8 of Set 14 | banda aceh
# Processing Record 9 of Set 14 | salaga
# Processing Record 10 of Set 14 | farmington
# Processing Record 11 of Set 14 | tsivilsk
# Processing Record 12 of Set 14 | marystown
# Processing Record 13 of Set 14 | fos-sur-mer
# Processing Record 14 of Set 14 | rozkishne
# Processing Record 15 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 16 of Set 14 | xining
# Processing Record 17 of Set 14 | morlaix
# Processing Record 18 of Set 14 | biskamzha
# Processing Record 19 of Set 14 | sars
# Processing Record 20 of Set 14 | honningsvag
# Processing Record 21 of Set 14 | tual
# Processing Record 22 of Set 14 | newark
# Processing Record 23 of Set 14 | cheremukhovo
# Processing Record 24 of Set 14 | venado
# Processing Record 25 of Set 14 | ureki
# Processing Record 26 of Set 14 | palmas
# Processing Record 27 of Set 14 | verkhnevilyuysk
# Processing Record 28 of Set 14 | cananeia
# Processing Record 29 of Set 14 | samarai
# Processing Record 30 of Set 14 | lethem
# Processing Record 31 of Set 14 | melnikovo
# Processing Record 32 of Set 14 | kushnarenkovo
# Processing Record 33 of Set 14 | darnah
# Processing Record 34 of Set 14 | montauban
# Processing Record 35 of Set 14 | nouadhibou
# Processing Record 36 of Set 14 | cayenne
# Processing Record 37 of Set 14 | mana
# Processing Record 38 of Set 14 | koumra
# Processing Record 39 of Set 14 | manor
# Processing Record 40 of Set 14 | bata
# Processing Record 41 of Set 14 | oktyabrskiy
# Processing Record 42 of Set 14 | kathmandu
# Processing Record 43 of Set 14 | koumac
# Processing Record 44 of Set 14 | taylorville
# Processing Record 45 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 46 of Set 14 | lerwick
# Processing Record 47 of Set 14 | mahadday weyne
# City not found. Skipping...
# Processing Record 48 of Set 14 | shankargarh
# Processing Record 49 of Set 14 | vostok
# Processing Record 50 of Set 14 | tromso
# Processing Record 1 of Set 15 | liberia
# Processing Record 2 of Set 15 | yibin
# Processing Record 3 of Set 15 | the hague
# Processing Record 4 of Set 15 | nyurba
# Processing Record 5 of Set 15 | bajo baudo
# City not found. Skipping...
# Processing Record 6 of Set 15 | polis
# Processing Record 7 of Set 15 | craig
# Processing Record 8 of Set 15 | krasnoselkup
# Processing Record 9 of Set 15 | along
# Processing Record 10 of Set 15 | mata
# Processing Record 11 of Set 15 | salinas
# Processing Record 12 of Set 15 | seminole
# Processing Record 13 of Set 15 | minot
# Processing Record 14 of Set 15 | dir
# Processing Record 15 of Set 15 | luba
# Processing Record 16 of Set 15 | umm kaddadah
# Processing Record 17 of Set 15 | kilindoni
# Processing Record 18 of Set 15 | leh
# Processing Record 19 of Set 15 | fort wellington
# Processing Record 20 of Set 15 | juneau
# Processing Record 21 of Set 15 | suntar
# Processing Record 22 of Set 15 | kyra
# Processing Record 23 of Set 15 | freital
# Processing Record 24 of Set 15 | tautira
# Processing Record 25 of Set 15 | zhigansk
# Processing Record 26 of Set 15 | panjakent
# Processing Record 27 of Set 15 | mayo
# Processing Record 28 of Set 15 | san cristobal
# Processing Record 29 of Set 15 | mahibadhoo
# Processing Record 30 of Set 15 | andenes
# Processing Record 31 of Set 15 | anaconda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 668

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Cape Town      ZA -33.9258   18.4232     54.01        70           0
# 1           Namibe      AO -15.1961   12.1522     67.26        93           2
# 2          Mataura      NZ -46.1927  168.8643     41.49        92          86
# 3           Albany      US  42.6001  -73.9662     79.14        58          32
# 4           Avarua      CK -21.2078 -159.7750     73.45        88          90
# ..             ...     ...      ...       ...       ...       ...         ...
# 663           Mayo      US  38.8876  -76.5119     87.12        45          47
# 664  San Cristobal      VE   7.7669  -72.2250     81.21        56          94
# 665     Mahibadhoo      MV   3.7833   72.9667     83.03        75          83
# 666        Andenes      NO  69.3143   16.1194     53.08        87          75
# 667       Anaconda      US  46.1285 -112.9423     76.96        15           0
#
#      Wind Speed Current Description
# 0          3.44           clear sky
# 1          6.87           clear sky
# 2          3.13     overcast clouds
# 3          5.55    scattered clouds
# 4          5.75     overcast clouds
# ..          ...                 ...
# 663        1.01    scattered clouds
# 664        7.63     overcast clouds
# 665        8.41       broken clouds
# 666        9.22       broken clouds
# 667       13.09           clear sky
#
# [668 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
